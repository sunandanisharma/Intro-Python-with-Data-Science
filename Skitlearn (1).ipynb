# %%
import pandas as pd
import sklearn.datasets as datasets

# %%
iris = datasets.load_iris()

# %%
data = pd.read_csv(r"C:\Users\hp\Downloads\iris.csv")

# %%
data.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data.sample(10)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 95            5.7          3.0           4.2          1.2  Versicolor
# 97            6.2          2.9           4.3          1.3  Versicolor
# 20            5.4          3.4           1.7          0.2      Setosa
# 12            4.8          3.0           1.4          0.1      Setosa
# 146           6.3          2.5           5.0          1.9   Virginica
# 82            5.8          2.7           3.9          1.2  Versicolor
# 102           7.1          3.0           5.9          2.1   Virginica
# 1             4.9          3.0           1.4          0.2      Setosa
# 74            6.4          2.9           4.3          1.3  Versicolor
# 18            5.7          3.8           1.7          0.3      Setosa

# %%
data.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
#The first one is the number of rows and 
# the other one is the number of columns.
data.shape
# Out:
# (150, 5)

# %%
print(data)
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
#data[start:end]
#start is inclusive whereas end is exclusive
print(data[10:21])
# it will print the rows from 10 to 20.
  
# you can also save it in a variable for further use in analysis
sliced_data=data[10:21]
print(sliced_data)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# 17           5.1          3.5           1.4          0.3  Setosa
# 18           5.7          3.8           1.7          0.3  Setosa
# 19           5.1          3.8           1.5          0.3  Setosa
# 20           5.4          3.4           1.7          0.2  Setosa
#     sepal.length  sepal.width  petal.length  petal.width variety
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# 16           5.4          3.9           1.3          0.4  Setosa
# 17           5.1          3.5           1.4          0.3  Setosa
# 18           5.7          3.8           1.7          0.3  Setosa
# 19           5.1          3.8           1.5          0.3  Setosa
# 20           5.4          3.4           1.7          0.2  Setosa

# %%
# data["column_name"].sum()
# extracting mean median mode particular column
sum_data = data["sepal.length"].sum()
mean_data = data["sepal.length"].mean()
median_data = data["sepal.length"].median()
  
print("Sum:",sum_data, "\nMean:", mean_data, "\nMedian:",median_data)
# Out:
# Sum: 876.5
# Mean: 5.843333333333335
# Median: 5.8

# %%
#: Extracting minimum and maximum from a column.
min_data=data["sepal.length"].min()
max_data=data["sepal.length"].max()
  
print("Minimum:",min_data, "\nMaximum:", max_data)
# Out:
# Minimum: 4.3
# Maximum: 7.9

# %%
#Adding a column to the dataset.
# For example, if we want to add a column let say "total_values", 
# that means if you want to add all the integer value of that particular
# row and get total answer in the new column "total_values".
# first we will extract the columns which have integer values.
cols = data.columns
  
# it will print the list of column names.
print(cols)
  
# we will take that columns which have integer values.
cols = cols[1:6]
  
# we will save it in the new dataframe variable
data1 = data[cols]
  
# now adding new column "total_values" to dataframe data.
data["total_values"]=data1[cols].sum(axis=1)
print(data)
# here axis=1 means you are working in rows, 
# whereas axis=0 means you are working in columns.
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width', 'variety',
#        'total_values'],
#       dtype='object')
#      sepal.length  sepal.width  petal.length  petal.width    variety  \
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
#      total_values
# 0            20.4
# 1            18.4
# 2            18.8
# 3            19.2
# 4            20.8
# ..            ...
# 145          42.0
# 146          37.6
# 147          40.8
# 148          44.4
# 149          39.6
#
# [150 rows x 6 columns]

# %%
# we will here print only the top 10 rows of the dataset, 
# if you want to see the result of the whole dataset remove 
#.head(10) from the below code
  
data.head(10).style.highlight_max(color='lightgreen', axis=0)
  
data.head(10).style.highlight_max(color='lightgreen', axis=1)
  
data.head(10).style.highlight_max(color='lightgreen', axis=None)
# Out:
# <style  type="text/css" >
#     #T_fdd81477_a766_11eb_a839_0068ebd4d848row5_col5 {
#             background-color:  lightgreen;
#         }</style><table id="T_fdd81477_a766_11eb_a839_0068ebd4d848" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sepal.length</th>        <th class="col_heading level0 col1" >sepal.width</th>        <th class="col_heading level0 col2" >petal.length</th>        <th class="col_heading level0 col3" >petal.width</th>        <th class="col_heading level0 col4" >variety</th>        <th class="col_heading level0 col5" >total_values</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row0_col0" class="data row0 col0" >5.100000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row0_col1" class="data row0 col1" >3.500000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row0_col2" class="data row0 col2" >1.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row0_col3" class="data row0 col3" >0.200000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row0_col4" class="data row0 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row0_col5" class="data row0 col5" >20.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row1_col0" class="data row1 col0" >4.900000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row1_col1" class="data row1 col1" >3.000000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row1_col2" class="data row1 col2" >1.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row1_col3" class="data row1 col3" >0.200000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row1_col4" class="data row1 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row1_col5" class="data row1 col5" >18.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row2_col0" class="data row2 col0" >4.700000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row2_col1" class="data row2 col1" >3.200000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row2_col2" class="data row2 col2" >1.300000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row2_col3" class="data row2 col3" >0.200000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row2_col4" class="data row2 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row2_col5" class="data row2 col5" >18.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row3_col0" class="data row3 col0" >4.600000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row3_col1" class="data row3 col1" >3.100000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row3_col2" class="data row3 col2" >1.500000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row3_col3" class="data row3 col3" >0.200000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row3_col4" class="data row3 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row3_col5" class="data row3 col5" >19.200000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row4_col0" class="data row4 col0" >5.000000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row4_col1" class="data row4 col1" >3.600000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row4_col2" class="data row4 col2" >1.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row4_col3" class="data row4 col3" >0.200000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row4_col4" class="data row4 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row4_col5" class="data row4 col5" >20.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row5_col0" class="data row5 col0" >5.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row5_col1" class="data row5 col1" >3.900000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row5_col2" class="data row5 col2" >1.700000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row5_col3" class="data row5 col3" >0.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row5_col4" class="data row5 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row5_col5" class="data row5 col5" >24.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row6_col0" class="data row6 col0" >4.600000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row6_col1" class="data row6 col1" >3.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row6_col2" class="data row6 col2" >1.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row6_col3" class="data row6 col3" >0.300000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row6_col4" class="data row6 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row6_col5" class="data row6 col5" >20.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row7_col0" class="data row7 col0" >5.000000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row7_col1" class="data row7 col1" >3.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row7_col2" class="data row7 col2" >1.500000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row7_col3" class="data row7 col3" >0.200000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row7_col4" class="data row7 col4" >Setosa</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row7_col5" class="data row7 col5" >20.400000</td>
#             </tr>
#             <tr>
#                         <th id="T_fdd81477_a766_11eb_a839_0068ebd4d848level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row8_col0" class="data row8 col0" >4.400000</td>
#                         <td id="T_fdd81477_a766_11eb_a839_0068ebd4d848row8_col1" class="data row8 col1" >2.900000</td>

# %%
#Cleaning and detecting missing values
data.isnull()
#if there is data is missing, it will display True else False.
# Out:
#      sepal.length  sepal.width  petal.length  petal.width  variety  \
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
#      total_values
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ..            ...
# 145         False
# 146         False
# 147         False
# 148         False
# 149         False
#
# [150 rows x 6 columns]
